# %% [markdown]
# ## Did you find an interesting article and want to easily find related research without browsing all existing publications yourself? Do you have a specific research question and want to discover relevant articles? Then this notebook might help you.
#
# **Approach**:
# We first discover a number of topics using LDA (Latent Dirichlet Allocation). This allows us to view each article as a mixture of these topics. By mapping a specific article into the topic space (a simplex with a topic in each corner), we can then find related articles.
#
#
# ---
# ### Website now available on [discovid.ai](https://discovid.ai)!
# Because of all the positive feedback and the growing interest in this recommendation system, we are now hosting it as a web service to make it more accessible to the broader public!
#
# Check out the following notebook for more information: https://www.kaggle.com/danielwolffram/discovid-ai-a-search-and-recommendation-engine.
# We now use a **whoosh search engine** as an initial search that allows complex boolean queries or to search specific fields (title, abstract, authors, journal, doi, methods). This topic model is then used to find related articles.
#
#
# ___
#
# ** Features**
# * Similarity measure to show the **confidence** in the recommendations
# * Plots that show the **topic-distribution** of an article
# * Select a **time range** to limit the articles that are considered (you can decide if you want to find the latest publications or search for insights in past research)
# * Option to only suggest **COVID-19-papers** (those that contain COVID-19, SARS-CoV-2, 2019-nCov, SARS Coronavirus 2 or 2019 Novel Coronavirus in the text body)
#
#
# **Pros**:
# * Doesn't only use the title or meta-data, but the actual content (text body) of the articles
# * Once trained, the model is easy and fast to apply
# * Helps to discover latent relationships between articles that might drive innovation
#
# **Cons**:
# * Unsupervised learning of topics is hard to verify
#
# ___
#
#
# Any feedback or feature requests are welcome!

# %% [markdown]
# ![Topic Space](https://inlovewithcode.files.wordpress.com/2017/02/screen-shot-2017-02-27-at-5-35-14-pm.png?w=1032&h=&zoom=2, width=50)

# %% [markdown]
# *Topic = Distribution over Words*
#
# *Document = Mixture of Topics*

# %% [markdown]
# Reference: https://www.youtube.com/watch?v=3mHy4OSyRf0&t=515s

# %% [markdown]
# # Install/Load Packages

# %% [markdown]
# *Internet access needs to be switched on for this to work!*

# %%
from IPython.utils import io
with io.capture_output() as captured:
    # !pip install scispacy
    # !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz

# %%
import numpy as np 
import pandas as pd

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import scispacy
import spacy
import en_core_sci_lg

from scipy.spatial.distance import jensenshannon

import joblib

from IPython.display import HTML, display

from ipywidgets import interact, Layout, HBox, VBox, Box
import ipywidgets as widgets
from IPython.display import clear_output

from tqdm import tqdm
from os.path import isfile

import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %% [markdown]
# # Load and Prepare Data

# %%
df = pd.read_csv('../input/cord-19-create-dataframe/cord19_df.csv')

# %%
df.head()
# Out:
#                                    paper_id  \
# 0  25621281691205eb015383cbac839182b838514f
# 1  7db22f7f81977109d493a0edf8ed75562648e839
# 2  a137eb51461b4a4ed3980aa5b9cb2f2c1cf0292a
# 3  6c3e1a43f0e199876d4bd9ff787e1911fd5cfaa6
# 4  2ce201c2ba233a562ee605a9aa12d2719cfa2beb
#
#                                            body_text  \
# 0  Influenza A viruses (IAV) are severe human pat...
# 1  The oldest known scorpions lived around 430 mi...
# 2  The emergence of Severe Acute Respiratory Synd...
# 3  Sjögren's syndrome (SS) is a connective tissue...
# 4  Human adenovirus (HAdV) is a common pathogen a...
#
#                                              methods  \
# 0  Cell culture. Wild type A549 human cells from ...
# 1  \nE. coli DH5a (maintained in our laboratory) ...
# 2  SARS-CoV MA15 (referred to as SARS-CoV through...
# 3  We searched the PubMed and Google Scholar data...
# 4  On June 30, 2016, one local Center for Disease...
#
#                                              results source  \
# 0  Identification of host cell factors required f...    NaN
# 1  The construct for Scorpine expression, contain...    PMC
# 2  To generate networks representing host respons...    PMC
# 3  SS is a chronic autoimmune “epithelitis” whose...    PMC
# 4  The outbreak ranged from June 21 to July 8, 20...    PMC
#
#                                                title  \
# 0                                                NaN
# 1  Recombinant Scorpine Produced Using SUMO Fusio...
# 2  The effect of inhibition of PP1 and TNFα signa...
# 3  Microbial Agents as Putative Inducers of B Cel...
# 4  A cluster of adenovirus type B55 infection in ...
#
#                             doi  \
# 0                           NaN
# 1  10.1371/journal.pone.0103456
# 2     10.1186/s12918-016-0336-6
# 3          10.1155/2019/8567364
# 4             10.1111/irv.12457
#
#                                             abstract publish_time  \
# 0  The human interferon (IFN)-induced MxA protein...          NaN
# 1  Scorpine, a small cationic peptide from the ve...   2014-07-28
# 2  BACKGROUND: The complex interplay between vira...   2016-09-23
# 3  INTRODUCTION: Understanding the mechanisms und...   2019-01-06
# 4  BACKGROUND: Human adenovirus type 55 is a re‐e...   2017-06-26
#
#                                              authors  \
# 0                                                NaN
# 1  Zhang, Chao; He, Xinlong; Gu, Yaping; Zhou, Hu...
# 2  McDermott, Jason E.; Mitchell, Hugh D.; Gralin...
# 3  Talotta, Rossella; Sarzi-Puttini, Piercarlo; A...
# 4  Yi, Lina; Zou, LiRong; Lu, Jing; Kang, Min; So...
#
#                           journal  \
# 0                             NaN
# 1                        PLoS One
# 2                   BMC Syst Biol
# 3                   J Immunol Res
# 4  Influenza Other Respir Viruses
#
#                                                  url  publish_year  \
# 0                                                NaN            -1
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...          2014
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          2016
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          2019
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          2017
#
#    is_covid19                                       study_design
# 0       False             ['protocol', 'p-value', 'association']
# 1       False                                             ['i2']
# 2       False    ['protocol', 'p-value', 'power', 'association']
# 3       False  ['β', 'etiology', 'surveillance', 'cohort', 'g...
# 4       False  ['gamma', 'surveillance', 'association', 'hete...

# %%
df.shape
# Out:
# (40186, 15)

# %% [markdown]
# We consider the text body, but the approach could also be applied to the abstracts only.

# %%
all_texts = df.body_text

# %%
# example snippet
all_texts[0][:500]
# Out:
# 'Influenza A viruses (IAV) are severe human pathogens all originating from their avian reservoir. Human-adapted IAV are the cause of annual epidemics but rarely also cause pandemics with millions of people succumbing to infection 1 . The recent emergence of "bird flu" viruses of the H5N1 and H7N9 subtype, with fatality rates among humans ranging up to ~50%, raises concern that these avian viruses might acquire the ability to transmit from human-to-human and initiate the next pandemic [1] [2] [3] '

# %% [markdown]
# # Latend Dirichlet Allocation

# %% [markdown]
# For preprocessing we use [scispaCy](https://allenai.github.io/scispacy/), which is a Python package containing [spaCy](https://spacy.io) models for processing biomedical, scientific or clinical text.

# %%
# medium model
nlp = en_core_sci_lg.load(disable=["tagger", "parser", "ner"])
nlp.max_length = 2000000

# %%
def spacy_tokenizer(sentence):
    return [word.lemma_ for word in nlp(sentence) if not (word.like_num or word.is_stop or word.is_punct or word.is_space or len(word)==1)]

# %%
# New stop words list 
customize_stop_words = [
    'doi', 'preprint', 'copyright', 'org', 'https', 'et', 'al', 'author', 'figure', 'table',
    'rights', 'reserved', 'permission', 'use', 'used', 'using', 'biorxiv', 'medrxiv', 'license', 'fig', 'fig.', 'al.', 'Elsevier', 'PMC', 'CZI',
    '-PRON-', 'usually',
    r'\usepackage{amsbsy', r'\usepackage{amsfonts', r'\usepackage{mathrsfs', r'\usepackage{amssymb', r'\usepackage{wasysym',
    r'\setlength{\oddsidemargin}{-69pt',  r'\usepackage{upgreek', r'\documentclass[12pt]{minimal'
]

# Mark them as stop words
for w in customize_stop_words:
    nlp.vocab[w].is_stop = True

# %%
filepath = '../input/topic-modeling-finding-related-articles/'

# %% [markdown]
# Generate files/models if they are not there yet.

# %%
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, min_df=2)
data_vectorized = vectorizer.fit_transform(tqdm(all_texts))
# Out:
# 100%|██████████| 40186/40186 [28:01<00:00, 23.89it/s]

# %%
data_vectorized.shape
# Out:
# (40186, 479400)

# %%
# vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, max_features=800000)
# data_vectorized = vectorizer.fit_transform(tqdm(all_texts))

# %%
# data_vectorized.shape # with bigrams: 6428134

# data_vectorized.shape # all 1.2 mio?

# %%
# most frequent words
word_count = pd.DataFrame({'word': vectorizer.get_feature_names(), 'count': np.asarray(data_vectorized.sum(axis=0))[0]})

word_count.sort_values('count', ascending=False).set_index('word')[:20].sort_values('count', ascending=True).plot(kind='barh')

# %%
joblib.dump(vectorizer, 'vectorizer.csv')
joblib.dump(data_vectorized, 'data_vectorized.csv')
# Out:
# ['data_vectorized.csv']

# %%
# if not (isfile(filepath + 'vectorizer.csv') & isfile(filepath + 'data_vectorized.csv')):
#     print('Files not there: generating')
#     vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, max_features=800000)
#     data_vectorized = vectorizer.fit_transform(tqdm(all_texts))
#     joblib.dump(vectorizer, 'vectorizer.csv')
#     joblib.dump(data_vectorized, 'data_vectorized.csv')

# else:
#     vectorizer = joblib.load(filepath + 'vectorizer.csv')
#     data_vectorized = joblib.load(filepath + 'data_vectorized.csv')

# %%
lda = LatentDirichletAllocation(n_components=50, random_state=0)
lda.fit(data_vectorized)
joblib.dump(lda, 'lda.csv')
# Out:
# ['lda.csv']

# %%
# # Train/Load Model
# if not (isfile(filepath + 'lda.csv')):
#     print('File not there: generating')
#     lda = LatentDirichletAllocation(n_components=50, random_state=0)
#     lda.fit(data_vectorized)

#     joblib.dump(lda, 'lda.csv')

# else:
#     lda = joblib.load(filepath + 'lda.csv')

# %% [markdown]
# ## Discovered Topics

# %%
def print_top_words(model, vectorizer, n_top_words):
    feature_names = vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        message = "\nTopic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
print_top_words(lda, vectorizer, n_top_words=25)
# Out:
# Topic #0: detection method target dna surface system assay nanoparticle technique application sample high probe develope detect technology test sensitivity result signal approach base different molecular device
#
# Topic #1: china hong kong chinese city urban increase passenger airport development change effect government emission year air area pollution flight energy economic beijing live zinc aircraft
#
# Topic #2: virus rna viral genome host replication mutation gene sequence protein plant synthesis genetic cell dna mutant polymerase translation rnas recombination region different nucleotide structure genomic
#
# Topic #3: cell virus infection culture viral medium expression show effect infect assay protein result entry line incubate activity replication control inhibit determine vero treatment level indicate
#
# Topic #4: patient infection antibiotic isolate resistance study strain s. result antimicrobial hospital method clinical aureus mrsa test bacterium treatment culture bacterial case rate resistant high control
#
# Topic #5: protein cell mm expression contain plasmid show antibody buff min express incubate result blot recombinant membrane wash purify describe medium clone vector gel indicate mutant
#
# Topic #6: bind mm structure activity residue rna show interaction complex concentration datum ph substrate reaction observe nm mutant site result enzyme form acid buff protein contain
#
# Topic #7: animal disease diarrhea cause intestinal horse rabbit small occur infection sign intestine result clinical include species calve day cattle affect large ferret c. associate treatment
#
# Topic #8: sequence gene genome codon read region analysis protein nucleotide site identify species human mutation find base dna length database alignment genomic library frameshifting position acid
#
# Topic #9: research system process technology new laboratory provide example study product need design approach science information method biological environment application development include work agent different require
#
# Topic #10: bind receptor lectin work domain interaction form complement dc-sign report mbl human protein activity ligand ceacam1 cell activation support influence submit role cancer complex signal
#
# Topic #11: study group calve participant age effect risk report high score analysis difference datum factor significant intervention sample include result measure individual compare find low variable
#
# Topic #12: strain sequence ibv isolate virus gene analysis genome sample phylogenetic study protein region nucleotide acid coronavirus show chicken genotype amino group tree s1 identity bird
#
# Topic #13: mers-cov bat human virus species host camel animal coronavirus mers transmission sars-cov infection cov study viral reservoir saudi infect covs include identify zoonotic outbreak find
#
# Topic #14: antibody serum sars-cov sars assay test sample elisa protein igg antigen positive plate show titer result patient control value high dilution study negative coronavirus detect
#
# Topic #15: ml sample concentration solution temperature water min virus time filter high add medium ph dry method surface increase volume remove study tube show result mm
#
# Topic #16: vaccine response vaccination antibody immune virus antigen vector immunization challenge study protection immunity development induce dna protein dose animal vaccinate human disease adjuvant trial clinical
#
# Topic #17: patient study treatment clinical asthma disease group therapy level severe day increase high acute risk result year symptom associate include mortality show exacerbation receive outcome
#
# Topic #18: pig pedv group prrsv day antibody piglet animal virus serum porcine sample tgev study infection control swine strain high cell infect herd show calve detect
#
# Topic #19: \usepackage{amsmath microarray array \begin{document dna \begin{document}$$ slide method \end{document \right \left tetherin sequence matrix function show spot group result different obtain value representation follow give
#
# Topic #20: cell mouse antibody cd8 response cd4 expression antigen human immune express show peptide infection day lymphocyte high result epitope clone nk culture tumor t-cell control
#
# Topic #21: protein peptide structure bind residue domain site sequence protease acid amino interaction fusion region form structural show cleavage complex molecule epitope motif position model pro
#
# Topic #22: compound activity drug effect antiviral inhibitor treatment cell inhibit show acid target study inhibition extract group derivative concentration active report agent vitro therapeutic treat effective
#
# Topic #23: patient influenza study respiratory infection case test symptom child virus hospital illness year day clinical age report include viral group datum high rate positive result
#
# Topic #24: infection virus respiratory rsv child study viral age detect sample year hmpv disease tract hrv human associate rhinovirus infant cause pathogen rv low detection asthma
#
# Topic #25: cat lesion disease cause occur sign feline infection dog case include result clinical animal affect cell fip tissue present common associate form fcov see skin
#
# Topic #26: health public care disease country need system include risk medical provide hospital outbreak information state work response control emergency national people service plan patient global
#
# Topic #27: cell infection response cytokine immune macrophage viral increase receptor activation production inflammatory expression virus role induce signal mechanism study effect level chemokine activate innate host
#
# Topic #28: virus influenza infection mouse human viral infect strain lung ha h5n1 cell day avian animal h1n1 study pandemic model respiratory titer show host replication disease
#
# Topic #29: virus membrane protein cell viral lipid replication virion particle fusion infection zikv er ebov entry host vesicle denv cellular gp formation assembly require rna study
#
# Topic #30: blood patient cause treatment infection disease increase case infant occur include therapy risk day fluid clinical associate acute fever pregnancy severe common present require rate
#
# Topic #31: sample pcr rna primer assay sequence virus dna viral detect reaction detection rt-pcr amplification probe gene result positive min test kit perform product method μl
#
# Topic #32: food bacterium water human product produce pathogen surface animal coli bacterial e. cause microorganism contaminate production include chemical exposure environmental contamination agent high reaction organism
#
# Topic #33: ace2 mouse cell expression rat brain neuron protein increase ang activity ii receptor show level effect study suggest function muscle result ace channel express control
#
# Topic #34: protein viral interaction virus cell domain rna activity signal bind rig-i function identify host cellular study complex pathway show role interact target infection ubiquitin replication
#
# Topic #35: market tourism cost model price industry economic impact effect result country study trade demand tourist variable business company change hotel increase crisis event travel value
#
# Topic #36: dog cat study canine disease concentration test clinical serum group university veterinary sample heart increase blood report compare result perform include high healthy case cardiac
#
# Topic #37: cell gene expression protein pathway infection viral signal ifn induce rna response activation target autophagy replication virus mrna apoptosis dna factor transcription type cellular host
#
# Topic #38: cell protein membrane surface acid glycoprotein receptor bind transport process antigen find golgi contain type enzyme study sialic molecule form antibody occur myelin present result
#
# Topic #39: cell disease ms mouse immune response patient study role expression increase receptor human model autoimmune activation effect induce level function inflammatory suggest associate cytokine show
#
# Topic #40: mouse cell antibody infection mhv protein virus sars-cov neutralize mabs viral infect mab epitope day show rbd brain coronavirus bind neutralization mers-cov result titer spike
#
# Topic #41: virus infection viral disease test infect antibody hepatitis agent cause cell culture detect rotavirus case occur laboratory clinical report transmission human infectious blood patient antigen
#
# Topic #42: pneumonia patient infection bacterial pathogen lung respiratory disease clinical case diagnosis include cause antibiotic culture cap study test treatment therapy bacterium pulmonary tb m. organism
#
# Topic #43: disease human animal population infection pathogen species transmission host case cause infectious country outbreak virus area risk increase include year spread fever new health infect
#
# Topic #44: case covid-19 report holder datum outbreak numb author/funder day peer-reviewed china sars-cov-2 available country estimate epidemic international display grant time infection perpetuity confirm rate death
#
# Topic #45: cell lung tissue live tumor epithelial increase epithelium rat cancer pulmonary airway disease alveolar bone include inflammation mouse type study injury normal fibrosis change cause
#
# Topic #46: air particle mask room droplet concentration airborne flow wind ventilation aerosol show study build respirator area size high pressure temperature low indoor velocity result surface
#
# Topic #47: group expression level mouse gene control day significantly study compare analysis animal show significant response increase infection tissue observe perform datum treatment difference high time
#
# Topic #48: model time individual numb rate epidemic transmission population parameter network case contact infection disease estimate value infect distribution probability datum infectious result dynamic assume give
#
# Topic #49: datum analysis method sample set model study identify value result test numb cluster information base different approach database high dataset score include algorithm network predict

# %% [markdown]
# Each article is a mixture of topics / a distribution over topics

# %%
doc_topic_dist = pd.DataFrame(lda.transform(data_vectorized))
doc_topic_dist.to_csv('doc_topic_dist.csv', index=False)

# %%
# if not (isfile(filepath + 'doc_topic_dist.csv')):
#         print('File not there: generating')
#         doc_topic_dist = pd.DataFrame(lda.transform(data_vectorized))
#         doc_topic_dist.to_csv('doc_topic_dist.csv', index=False)
# else:
#         doc_topic_dist = pd.read_csv(filepath + 'doc_topic_dist.csv')

# %%
doc_topic_dist.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.000007  0.000007  0.000007  0.403858  0.000007  0.001450  0.044364
# 1  0.009363  0.005548  0.000011  0.000011  0.141706  0.475036  0.000011
# 2  0.000007  0.000007  0.000007  0.000007  0.000007  0.000007  0.000007
# 3  0.000006  0.000006  0.047541  0.000006  0.009125  0.000006  0.000006
# 4  0.000014  0.000014  0.000014  0.000014  0.000014  0.000014  0.000014
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.000007  0.036174  0.000007  ...  0.000007  0.000007  0.000007  0.000007
# 1  0.037033  0.000011  0.000011  ...  0.000011  0.000011  0.000011  0.028808
# 2  0.000007  0.000007  0.000007  ...  0.085671  0.000007  0.000007  0.000007
# 3  0.000006  0.016317  0.000006  ...  0.000006  0.015339  0.014015  0.000006
# 4  0.000014  0.000014  0.003107  ...  0.000014  0.000014  0.000014  0.000014
#
#          44        45        46        47        48        49
# 0  0.000007  0.000007  0.000007  0.000007  0.000007  0.077385
# 1  0.000011  0.000011  0.000011  0.000011  0.000011  0.000011
# 2  0.000007  0.000007  0.000007  0.139552  0.008610  0.399068
# 3  0.000006  0.103058  0.000006  0.000006  0.000006  0.008535
# 4  0.067418  0.000014  0.016586  0.000014  0.000014  0.000014
#
# [5 rows x 50 columns]

# %% [markdown]
# # Get Nearest Papers (in Topic Space)

# %%
is_covid19_article = df.body_text.str.contains('COVID-19|SARS-CoV-2|2019-nCov|SARS Coronavirus 2|2019 Novel Coronavirus')

# %%
def get_k_nearest_docs(doc_dist, k=5, lower=1950, upper=2020, only_covid19=False, get_dist=False):
    '''
    doc_dist: topic distribution (sums to 1) of one article
    
    Returns the index of the k nearest articles (as by Jensen–Shannon divergence in topic space). 
    '''
    
    relevant_time = df.publish_year.between(lower, upper)
    
    if only_covid19:
        temp = doc_topic_dist[relevant_time & is_covid19_article]
        
    else:
        temp = doc_topic_dist[relevant_time]
         
    distances = temp.apply(lambda x: jensenshannon(x, doc_dist), axis=1)
    k_nearest = distances[distances != 0].nsmallest(n=k).index
    
    if get_dist:
        k_distances = distances[distances != 0].nsmallest(n=k)
        return k_nearest, k_distances
    else:
        return k_nearest

# %%
# d = get_k_nearest_docs(doc_topic_dist[df.paper_id == '90b5ecf991032f3918ad43b252e17d1171b4ea63'].iloc[0])

# sb.kdeplot(d)

# %%
def plot_article_dna(paper_id, width=20):
    t = df[df.paper_id == paper_id].title.values[0]
    doc_topic_dist[df.paper_id == paper_id].T.plot(kind='bar', legend=None, title=t, figsize=(width, 4))
    plt.xlabel('Topic')

def compare_dnas(paper_id, recommendation_id, width=20):
    t = df[df.paper_id == recommendation_id].title.values[0]
    temp = doc_topic_dist[df.paper_id == paper_id]
    ymax = temp.max(axis=1).values[0]*1.25
    temp = pd.concat([temp, doc_topic_dist[df.paper_id == recommendation_id]])
    temp.T.plot(kind='bar', title=t, figsize=(width, 4), ylim= [0, ymax])
    plt.xlabel('Topic')
    plt.legend(['Selection', 'Recommendation'])

# compare_dnas('90b5ecf991032f3918ad43b252e17d1171b4ea63', 'a137eb51461b4a4ed3980aa5b9cb2f2c1cf0292a')

def dna_tabs(paper_ids):
    k = len(paper_ids)
    outs = [widgets.Output() for i in range(k)]

    tab = widgets.Tab(children = outs)
    tab_titles = ['Paper ' + str(i+1) for i in range(k)]
    for i, t in enumerate(tab_titles):
        tab.set_title(i, t)
    display(tab)

    for i, t in enumerate(tab_titles):
        with outs[i]:
            ax = plot_article_dna(paper_ids[i])
            plt.show(ax)

def compare_tabs(paper_id, recommendation_ids):
    k = len(recommendation_ids)
    outs = [widgets.Output() for i in range(k)]

    tab = widgets.Tab(children = outs)
    tab_titles = ['Paper ' + str(i+1) for i in range(k)]
    for i, t in enumerate(tab_titles):
        tab.set_title(i, t)
    display(tab)

    for i, t in enumerate(tab_titles):
        with outs[i]:
            ax = compare_dnas(paper_id, recommendation_ids[i])
            plt.show(ax)

# %% [markdown]
# # Search related papers to a chosen one

# %% [markdown]
# As a similarity measure we use 1 - Jensen-Shannon distance.

# %%
def recommendation(paper_id, k=5, lower=1950, upper=2020, only_covid19=False, plot_dna=False):
    '''
    Returns the title of the k papers that are closest (topic-wise) to the paper given by paper_id.
    '''
    
    print(df.title[df.paper_id == paper_id].values[0])

    recommended, dist = get_k_nearest_docs(doc_topic_dist[df.paper_id == paper_id].iloc[0], k, lower, upper, only_covid19, get_dist=True)
    recommended = df.iloc[recommended].copy()
    recommended['similarity'] = 1 - dist 
    
    h = '<br/>'.join(['<a href="' + l + '" target="_blank">'+ n + '</a>' +' (Similarity: ' + "{:.2f}".format(s) + ')' for l, n, s in recommended[['url','title', 'similarity']].values])
    display(HTML(h))
    
    if plot_dna:
        compare_tabs(paper_id, recommended.paper_id.values)

# %%
recommendation('a137eb51461b4a4ed3980aa5b9cb2f2c1cf0292a', k=5, plot_dna=True)
# Out:
# The effect of inhibition of PP1 and TNFα signaling on pathogenesis of SARS coronavirus
# <a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3297540/" target="_blank">A chemokine gene expression signature derived from meta-analysis predicts the pathogenicity of viral respiratory infections</a> (Similarity: 0.70)<br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7089064/" target="_blank">Bioinformatics Analysis of Genes and Pathways of CD11b(+)/Ly6C(intermediate) Macrophages after Renal Ischemia-Reperfusion Injury</a> (Similarity: 0.68)<br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5473748/" target="_blank">Oas1b-dependent Immune Transcriptional Profiles of West Nile Virus Infection in the Collaborative Cross</a> (Similarity: 0.65)<br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4436129/" target="_blank">Multiplexed Component Analysis to Identify Genes Contributing to the Immune Response during Acute SIV Infection</a> (Similarity: 0.64)<br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3623894/" target="_blank">Pig immune response to general stimulus and to porcine reproductive and respiratory syndrome virus infection: a meta-analysis approach</a> (Similarity: 0.63)
# Tab(children=(Output(), Output(), Output(), Output(), Output()), _titles={'0': 'Paper 1', '1': 'Paper 2', '2':…

# %%
recommendation('a137eb51461b4a4ed3980aa5b9cb2f2c1cf0292a', k=5, only_covid19=True, plot_dna=True)
# Out:
# The effect of inhibition of PP1 and TNFα signaling on pathogenesis of SARS coronavirus
# <a href="https://doi.org/10.1101/2020.02.19.957118" target="_blank">Mucin 4 Protects Female Mice from Coronavirus Pathogenesis</a> (Similarity: 0.53)<br/><a href="https://doi.org/10.1101/2020.04.12.025577" target="_blank">Mechanistic modeling of the SARS-CoV-2 disease map</a> (Similarity: 0.49)<br/><a href="https://doi.org/10.1101/2020.02.27.967588" target="_blank">TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection</a> (Similarity: 0.48)<br/><a href="https://doi.org/10.1101/2020.02.24.20025437" target="_blank">TWIRLS, an automated topic-wise inference method based on massive literature, suggests a possible mechanism via ACE2 for the pathological changes in the human host after coronavirus infection</a> (Similarity: 0.48)<br/><a href="https://doi.org/10.1101/2020.04.07.030734" target="_blank">Reversal of Infected Host Gene Expression Identifies Repurposed Drug Candidates for COVID-19</a> (Similarity: 0.46)
# Tab(children=(Output(), Output(), Output(), Output(), Output()), _titles={'0': 'Paper 1', '1': 'Paper 2', '2':…

# %%
recommendation('90b5ecf991032f3918ad43b252e17d1171b4ea63', k=5, only_covid19=False, plot_dna=True)
# Out:
# The role of absolute humidity on transmission rates of the COVID-19 outbreak
# <a href="https://doi.org/10.1101/2020.02.19.20025452" target="_blank">The serial interval of COVID-19 from publicly reported confirmed cases</a> (Similarity: 0.86)<br/><a href="https://doi.org/10.1101/2020.02.06.20020941" target="_blank">Analysis of the epidemic growth of the early 2019-nCoV outbreak using internationally confirmed cases</a> (Similarity: 0.84)<br/><a href="https://doi.org/10.1101/2020.02.15.20023440" target="_blank">Evaluating new evidence in the early dynamics of the novel coronavirus COVID-19 outbreak in Wuhan, China with real time domestic traffic and potential asymptomatic transmissions</a> (Similarity: 0.84)<br/><a href="https://doi.org/10.1101/2020.03.01.20029819" target="_blank">COVID-19 Epidemic Outside China: 34 Founders and Exponential Growth</a> (Similarity: 0.84)<br/><a href="https://doi.org/10.1101/2020.03.14.20036178" target="_blank">Correcting under-reported COVID-19 case numbers</a> (Similarity: 0.83)
# Tab(children=(Output(), Output(), Output(), Output(), Output()), _titles={'0': 'Paper 1', '1': 'Paper 2', '2':…

# %%
recommendation('c04c7fb330a409a00f67040dde0f83b3da88eacb', k=5, only_covid19=True, plot_dna=True)
# Out:
# Potential inhibitors for 2019-nCoV coronavirus M protease from clinically approved medicines
# <a href="https://doi.org/10.1016/j.tmaid.2020.101646" target="_blank">A search for medications to treat COVID-19 via in silico molecular docking models of the SARS-CoV-2 spike glycoprotein and 3CL protease</a> (Similarity: 0.72)<br/><a href="https://doi.org/10.1016/j.jpha.2020.03.009" target="_blank">Structural basis of SARS-CoV-2 3CLpro and anti-COVID-19 drug discovery from medicinal plants †</a> (Similarity: 0.72)<br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7062204/" target="_blank">Prediction of the SARS-CoV-2 (2019-nCoV) 3C-like protease (3CL (pro)) structure: virtual screening reveals velpatasvir, ledipasvir, and other drug repurposing candidates</a> (Similarity: 0.72)<br/><a href="https://doi.org/10.1101/2020.01.31.929695" target="_blank">Molecular Modeling Evaluation of the Binding Effect of Ritonavir, Lopinavir and Darunavir to Severe Acute Respiratory Syndrome Coronavirus 2 Proteases</a> (Similarity: 0.72)<br/><a href="https://doi.org/10.1101/2020.04.07.029132" target="_blank">A virus that has gone viral: Amino acid mutation in S protein of Indian isolate of Coronavirus COVID-19 might impact receptor binding and thus infectivity</a> (Similarity: 0.70)
# Tab(children=(Output(), Output(), Output(), Output(), Output()), _titles={'0': 'Paper 1', '1': 'Paper 2', '2':…

# %%
recommendation('36521caf90f471c9da1a4e84f8562440d73ead9a', k=5, plot_dna=True)
# Out:
# Estimation of the epidemic properties of the 2019 novel coronavirus: A mathematical modeling study
# <a href="https://doi.org/10.1101/2020.04.01.20049825" target="_blank">SEIR and Regression Model based COVID-19 outbreak predictions in India</a> (Similarity: 0.89)<br/><a href="https://doi.org/10.1101/2020.02.13.20022251" target="_blank">Understanding the present status and forecasting of COVID―19 in Wuhan</a> (Similarity: 0.88)<br/><a href="https://doi.org/10.1101/2020.03.21.20040139" target="_blank">Tracking and forecasting milepost moments of the epidemic in the early-outbreak: framework and applications to the COVID-19</a> (Similarity: 0.87)<br/><a href="https://doi.org/10.20535/ibb.2020.4.1.195074" target="_blank">Statistics-Based Predictions of Coronavirus Epidemic Spreading in Mainland China</a> (Similarity: 0.87)<br/><a href="https://doi.org/10.1101/2020.03.27.20045104" target="_blank">Prediction of the time evolution of the Covid-19 Pandemic in Italy by a Gauss Error Function and Monte Carlo simulations</a> (Similarity: 0.86)
# Tab(children=(Output(), Output(), Output(), Output(), Output()), _titles={'0': 'Paper 1', '1': 'Paper 2', '2':…

# %% [markdown]
# # Widget: Pick a COVID-19-Paper

# %% [markdown]
# This makes it easier to pick a paper (you don't have to search the paper_id).

# %%
def related_papers():
    '''
    Creates a widget where you can select one of many papers about covid-19 and then displays related articles from the whole dataset.
    '''
    covid_papers = df[df.body_text.str.contains('COVID-19|SARS-CoV-2|2019-nCov|SARS Coronavirus 2|2019 Novel Coronavirus')][['paper_id', 'title']] # are there more names?
    title_to_id = covid_papers.set_index('title')['paper_id'].to_dict()
    
    def main_function(bullet, k=5, year_range=[1950, 2020], only_covid19=False):
        recommendation(title_to_id[bullet], k, lower=year_range[0], upper=year_range[1], only_covid19=only_covid19)
    
    yearW = widgets.IntRangeSlider(min=1950, max=2020, value=[2010, 2020], description='Year Range', 
                                   continuous_update=False, layout=Layout(width='40%'))
    covidW = widgets.Checkbox(value=False,description='Only COVID-19-Papers',disabled=False, indent=False, layout=Layout(width='20%'))
    kWidget = widgets.IntSlider(value=10, description='k', max=50, min=1, layout=Layout(width='20%'))

    bulletW = widgets.Select(options=title_to_id.keys(), layout=Layout(width='90%', height='200px'), description='Title:')

    widget = widgets.interactive(main_function, bullet=bulletW, k=kWidget, year_range=yearW, only_covid19=covidW)

    controls = VBox([Box(children=[widget.children[:-1][1], widget.children[:-1][2], widget.children[:-1][3]], 
                         layout=Layout(justify_content='space-around')), widget.children[:-1][0]])
    output = widget.children[-1]
    display(VBox([controls, output]))

# %%
related_papers()
# Out:
# VBox(children=(VBox(children=(Box(children=(IntSlider(value=10, description='k', layout=Layout(width='20%'), m…

# %% [markdown]
# # Browse Tasks

# %% [markdown]
# We can now also map a task or bullet point into the topic space and find related articles that might help to solve the question at hand.
#
# Note: Some of the bullet points are very short - results might not be reliable in this case.

# %%
task1 = ["Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.",
"Prevalence of asymptomatic shedding and transmission (e.g., particularly children).",
"Seasonality of transmission.",
"Physical science of the coronavirus (e.g., charge distribution, adhesion to hydrophilic/phobic surfaces, environmental survival to inform decontamination efforts for affected areas and provide information about viral shedding).",
"Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).",
"Persistence of virus on surfaces of different materials (e,g., copper, stainless steel, plastic).",
"Natural history of the virus and shedding of it from an infected person",
"Implementation of diagnostics and products to improve clinical processes",
"Disease models, including animal models for infection, disease and transmission",
"Tools and studies to monitor phenotypic change and potential adaptation of the virus",
"Immune response and immunity",
"Effectiveness of movement control strategies to prevent secondary transmission in health care and community settings",
 "Effectiveness of personal protective equipment (PPE) and its usefulness to reduce risk of transmission in health care and community settings",
"Role of the environment in transmission"]

task2 = ['Data on potential risks factors',
'Smoking, pre-existing pulmonary disease',
'Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities',
'Neonates and pregnant women',
'Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.',
'Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors', 
'Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups',
'Susceptibility of populations',
'Public health mitigation measures that could be effective for control']

task3 = ['Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.',
'Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.',
'Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.',
'Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.',
'Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.',
'Experimental infections to test host range for this pathogen.',
'Animal host(s) and any evidence of continued spill-over to humans',
'Socioeconomic and behavioral risk factors for this spill-over',
'Sustainable risk reduction strategies']

task4 = ["Guidance on ways to scale up NPIs in a more coordinated way (e.g., establish funding, infrastructure and authorities to support real time, authoritative (qualified participants) collaboration with all states to gain consensus on consistent guidance and to mobilize resources to geographic areas where critical shortfalls are identified) to give us time to enhance our health care delivery system capacity to respond to an increase in cases.",
"Rapid design and execution of experiments to examine and compare NPIs currently being implemented. DHS Centers for Excellence could potentially be leveraged to conduct these experiments.",
"Rapid assessment of the likely efficacy of school closures, travel bans, bans on mass gatherings of various sizes, and other social distancing approaches.",
"Methods to control the spread in communities, barriers to compliance and how these vary among different populations..",
"Models of potential interventions to predict costs and benefits that take account of such factors as race, income, disability, age, geographic location, immigration status, housing status, employment status, and health insurance status.",
"Policy changes necessary to enable the compliance of individuals with limited resources and the underserved with NPIs.",
"Research on why people fail to comply with public health advice, even if they want to do so (e.g., social or financial costs may be too high).",
"Research on the economic impact of this or any pandemic. This would include identifying policy and programmatic alternatives that lessen/mitigate risks to critical government services, food distribution and supplies, access to critical household supplies, and access to health diagnoses, treatment, and needed care, regardless of ability to pay."]

task5 = ["Effectiveness of drugs being developed and tried to treat COVID-19 patients. Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication.",
"Methods evaluating potential complication of Antibody-Dependent Enhancement (ADE) in vaccine recipients.",
"Exploration of use of best animal models and their predictive value for a human vaccine.",
"Capabilities to discover a therapeutic (not vaccine) for the disease, and clinical effectiveness studies to discover therapeutics, to include antiviral agents.",
"Alternative models to aid decision makers in determining how to prioritize and distribute scarce, newly proven therapeutics as production ramps up. This could include identifying approaches for expanding production capacity to ensure equitable and timely distribution to populations in need.",
"Efforts targeted at a universal coronavirus vaccine.",
"Efforts to develop animal models and standardize challenge studies",
"Efforts to develop prophylaxis clinical studies and prioritize in healthcare workers",
"Approaches to evaluate risk for enhanced disease after vaccination",
"Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models [in conjunction with therapeutics]"]

task6 = ["Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019", 
"Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight",
"Efforts to support sustained education, access, and capacity building in the area of ethics",
"Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences.",
"Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures)",
"Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed.",
"Efforts to identify the underlying drivers of fear, anxiety and stigma that fuel misinformation and rumor, particularly through social media."]

task7 = ["How widespread current exposure is to be able to make immediate policy recommendations on mitigation measures. Denominators for testing and a mechanism for rapidly sharing that information, including demographics, to the extent possible. Sampling methods to determine asymptomatic disease (e.g., use of serosurveys (such as convalescent samples) and early detection of disease (e.g., use of screening of neutralizing antibodies such as ELISAs).",
"Efforts to increase capacity on existing diagnostic platforms and tap into existing surveillance platforms.",
"Recruitment, support, and coordination of local expertise and capacity (public, private—commercial, and non-profit, including academic), including legal, ethical, communications, and operational issues.",
"National guidance and guidelines about best practices to states (e.g., how states might leverage universities and private laboratories for testing purposes, communications to public health officials and the public).",
"Development of a point-of-care test (like a rapid influenza test) and rapid bed-side tests, recognizing the tradeoffs between speed, accessibility, and accuracy.",
"Rapid design and execution of targeted surveillance experiments calling for all potential testers using PCR in a defined area to start testing and report to a specific entity. These experiments could aid in collecting longitudinal samples, which are critical to understanding the impact of ad hoc local interventions (which also need to be recorded).",
"Separation of assay development issues from instruments, and the role of the private sector to help quickly migrate assays onto those devices.",
"Efforts to track the evolution of the virus (i.e., genetic drift or mutations) and avoid locking into specific reagents and surveillance/detection schemes.",
"Latency issues and when there is sufficient viral load to detect the pathogen, and understanding of what is needed in terms of biological and environmental sampling.",
"Use of diagnostics such as host response markers (e.g., cytokines) to detect early disease or predict severe disease progression, which would be important to understanding best clinical practice and efficacy of therapeutic interventions.",
"Policies and protocols for screening and testing.",
"Policies to mitigate the effects on supplies associated with mass testing, including swabs and reagents.",
"Technology roadmap for diagnostics.",
"Barriers to developing and scaling up new diagnostic tests (e.g., market forces), how future coalition and accelerator models (e.g., Coalition for Epidemic Preparedness Innovations) could provide critical funding for diagnostics, and opportunities for a streamlined regulatory environment.",
"New platforms and technology (e.g., CRISPR) to improve response times and employ more holistic approaches to COVID-19 and future diseases.",
"Coupling genomics and diagnostic testing on a large scale.",
"Enhance capabilities for rapid sequencing and bioinformatics to target regions of the genome that will allow specificity for a particular variant.",
"Enhance capacity (people, technology, data) for sequencing with advanced analytics for unknown pathogens, and explore capabilities for distinguishing naturally-occurring pathogens from intentional.",
"One Health surveillance of humans and potential sources of future spillover or ongoing exposure for this organism and future pathogens, including both evolutionary hosts (e.g., bats) and transmission hosts (e.g., heavily trafficked and farmed wildlife and domestic food and companion species), inclusive of environmental, demographic, and occupational risk factors."]

task8 = ["Resources to support skilled nursing facilities and long term care facilities.",
"Mobilization of surge medical staff to address shortages in overwhelmed communities",
"Age-adjusted mortality data for Acute Respiratory Distress Syndrome (ARDS) with/without other organ failure – particularly for viral etiologies",
"Extracorporeal membrane oxygenation (ECMO) outcomes data of COVID-19 patients",
"Outcomes data for COVID-19 after mechanical ventilation adjusted for age.",
"Knowledge of the frequency, manifestations, and course of extrapulmonary manifestations of COVID-19, including, but not limited to, possible cardiomyopathy and cardiac arrest.",
"Application of regulatory standards (e.g., EUA, CLIA) and ability to adapt care to crisis standards of care level.",
"Approaches for encouraging and facilitating the production of elastomeric respirators, which can save thousands of N95 masks.",
"Best telemedicine practices, barriers and faciitators, and specific actions to remove/expand them within and across state boundaries.",
"Guidance on the simple things people can do at home to take care of sick people and manage disease.",
"Oral medications that might potentially work.",
"Use of AI in real-time health care delivery to evaluate interventions, risk factors, and outcomes in a way that could not be done manually.",
"Best practices and critical challenges and innovative solutions and technologies in hospital flow and organization, workforce protection, workforce allocation, community-based support resources, payment, and supply chain management to enhance capacity, efficiency, and outcomes.",
"Efforts to define the natural history of disease to inform clinical care, public health interventions, infection prevention control, transmission, and clinical trials",
"Efforts to develop a core clinical outcome set to maximize usability of data across a range of trials",
"Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen)"]

task9 = ["Methods for coordinating data-gathering with standardized nomenclature.",
"Sharing response information among planners, providers, and others.",
"Understanding and mitigating barriers to information-sharing.",
"How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic).",
"Integration of federal/state/local public health surveillance systems.",
"Value of investments in baseline public health response infrastructure preparedness",
"Modes of communicating with target high-risk populations (elderly, health care workers).",
"Risk communication and guidelines that are easy to understand and follow (include targeting at risk populations’ families too).",
"Communication that indicates potential risk of disease to all population groups.",
"Misunderstanding around containment and mitigation.",
"Action plan to mitigate gaps and problems of inequity in the Nation’s public health capability, capacity, and funding to ensure all citizens in need are supported and can access information, surveillance, and treatment.",
"Measures to reach marginalized and disadvantaged populations.",
"Data systems and research priorities and agendas incorporate attention to the needs and circumstances of disadvantaged populations and underrepresented minorities.",
"Mitigating threats to incarcerated people from COVID-19, assuring access to information, prevention, diagnosis, and treatment.",
"Understanding coverage policies (barriers and opportunities) related to testing, treatment, and care"]

tasks={'What is known about transmission, incubation, and environmental stability?': task1,
       'What do we know about COVID-19 risk factors?': task2, 
       'What do we know about virus genetics, origin, and evolution?': task3, 
       'What do we know about non-pharmaceutical interventions?': task4,
       'What do we know about vaccines and therapeutics?': task5, 
       'What has been published about ethical and social science considerations?': task6, 
       'What do we know about diagnostics and surveillance?': task7,
       'What has been published about medical care?': task8, 
       'What has been published about information sharing and inter-sectoral collaboration?': task9}

# %%
# def relevant_articles(tasks, k=3, lower=1950, upper=2020, only_covid19=False):
#     tasks = [tasks] if type(tasks) is str else tasks 
    
#     tasks_tf = tf_vectorizer.transform(tasks)
#     tasks_topic_dist = pd.DataFrame(lda_tf.transform(tasks_tf))

#     for index, bullet in enumerate(tasks):
#         print(bullet)
#         recommended = get_k_nearest_docs(tasks_topic_dist.iloc[index], k, lower, upper, only_covid19)
#         recommended = all_data.iloc[recommended]

#         recommended[['paper_id','title', 'abstract']].to_csv('task' + str(index) + '.csv')

# %%
def relevant_articles(tasks, k=3, lower=1950, upper=2020, only_covid19=False):
    tasks = [tasks] if type(tasks) is str else tasks 
    
    tasks_vectorized = vectorizer.transform(tasks)
    tasks_topic_dist = pd.DataFrame(lda.transform(tasks_vectorized))

    for index, bullet in enumerate(tasks):
        print(bullet)
        recommended = get_k_nearest_docs(tasks_topic_dist.iloc[index], k, lower, upper, only_covid19)
        recommended = df.iloc[recommended]

        h = '<br/>'.join(['<a href="' + l + '" target="_blank">'+ n + '</a>' for l, n in recommended[['url','title']].values])
        display(HTML(h))

# %% [markdown]
# ## What is known about transmission, incubation, and environmental stability?

# %%
relevant_articles(task1, 5, only_covid19=True)
# Out:
# Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.
# <a href="https://doi.org/10.1101/2020.02.21.20026146" target="_blank">Public Exposure to Live Animals, Behavioural Change, and Support in Containment Measures in response to COVID-19 Outbreak: a population-based cross sectional survey in China</a><br/><a href="https://doi.org/10.1101/2020.04.03.20052563" target="_blank">Interaction between malarial transmission and BCG vaccination with COVID-19 incidence in the world map: A changing landscape human immune system?</a><br/><a href="https://doi.org/10.1016/s2214-109x(20)30123-6" target="_blank">COVID-19 pandemic in west Africa</a><br/><a href="https://doi.org/10.1101/2020.04.08.20058719" target="_blank">Temporal rise in the proportion of both younger adults and older adolescents among COVID-19 cases in Germany: evidence of lesser adherence to social distancing practices?</a><br/><a href="https://doi.org/10.1016/j.tmaid.2020.101656" target="_blank">COVID-19 and dengue, co-epidemics in Ecuador and other countries in Latin America: Pushing strained health care systems over the edge</a>
# Prevalence of asymptomatic shedding and transmission (e.g., particularly children).
# <a href="https://doi.org/10.1016/j.mehy.2020.109689" target="_blank">Routine childhood immunization may protect against COVID-19</a><br/><a href="https://doi.org/10.1016/j.rbmo.2020.04.004" target="_blank">COVID-19: should we continue to cryopreserve sperm during the pandemic?</a><br/><a href="https://doi.org/10.1016/s2468-1253(20)30085-6" target="_blank">Viral screening before initiation of biologics in patients with inflammatory bowel disease during the COVID-19 outbreak</a><br/><a href="https://doi.org/10.1016/j.ijid.2020.03.080" target="_blank">The serostatus approach to fighting COVID-19</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC
a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7063764/" target="_blank">The impact of point-of-care testing for influenza A and B on patient flow and management in a medical assessment unit of a general hospital</a>
# Susceptibility of populations
# <a href="https://doi.org/10.1016/j.jobb.2020.02.001" target="_blank">Deliberate release: Plague – A review</a><br/><a href="https://doi.org/10.1016/j.jinf.2020.02.011" target="_blank">Chinese medical personnel against the 2019-nCoV</a><br/><a href="https://doi.org/10.1016/j.jmii.2020.03.034" target="_blank">Treatment options for COVID-19: the reality and challenges</a><br/><a href="https://doi.org/10.1016/j.mehy.2020.109706" target="_blank">Correlation between atmospheric particulate matter and antibiotic resistance: A hypothesis</a><br/><a href="https://doi.org/10.1016/j.envint.2020.105689" target="_blank">Future Perspectives of Wastewater-Based Epidemiology: Monitoring Infectious Disease Spread and Resistance to the Community Level</a>
# Public health mitigation measures that could be effective for control
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.sapharm.2020.04.002" target="_blank">Pharmacy Emergency Preparedness and Response (PEPR) framework for expanding pharmacy professionals’ roles and contributions to emergency preparedness and response during the COVID-19 pandemic and beyond</a>

# %% [markdown]
# ## What do we know about virus genetics, origin, and evolution?

# %%
relevant_articles(task3, 5, only_covid19=True)
# Out:
# Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.
# <a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7149283/" target="_blank">BDA Indemnity supports members with immediate cost reductions of up to 80%</a><br/><a href="https://doi.org/10.1016/j.jsurg.2020.03.020" target="_blank">Virtual Interviews in the Era of COVID-19: A Primer for Applicants</a><br/><a href="https://doi.org/10.1016/j.arcmed.2020.04.003" target="_blank">Global Threat of SARS-CoV-2/COVID-19 and the Need for More and Better Diagnostic Tools</a><br/><a href="https://doi.org/10.1016/j.gerinurse.2020.03.012" target="_blank">COVID‐19 Presents High Risk to Older Persons</a><br/><a href="https://doi.org/10.1016/j.invent.2020.100317" target="_blank">The COVID-19 pandemic: The ‘black swan’ for mental health care and a turning point for e-health</a>
# Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.
# <a href="https://doi.org/10.1101/2020.03.02.974311" target="_blank">Partial RdRp sequences offer a robust method for Coronavirus subgenus classification</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7152572/" target="_blank">Coronavirus Goes Viral: Quantifying the COVID-19 Misinformation Epidemic on Twitter</a><br/><a href="https://doi.org/10.1101/2020.03.30.20047308" target="_blank">Predicting Mortality Risk in Patients with COVID-19 Using Artificial Intelligence to Help Medical Decision-Making</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7093988/" target="_blank">Using the spike protein feature to predict infection risk and monitor the evolutionary dynamic of coronavirus</a><br/><a href="https://doi.org/10.1101/2020.04.03.020602" target="_blank">Real-time biomedical knowledge synthesis of the exponentially growing world wide web using unsupervised neural networks</a>
# Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.
# <a href="https://doi.org/10.1016/j.tim.2020.04.001" target="_blank">Pangolins Harbor SARS-CoV-2-related Coronaviruses</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7098031/" target="_blank">Zoonotic origins of human coronaviruses</a><br/><a href="https://doi.org/10.1016/s0140-6736(20)30557-2" target="_blank">SARS-CoV-2 is an appropriate name for the new coronavirus</a><br/><a href="https://doi.org/10.1016/j.micinf.2020.03.003" target="_blank">Predicting the angiotensin converting enzyme 2 (ACE2) utilizing capability as the receptor of SARS-CoV-2</a><br/><a href="https://doi.org/10.3390/ijerph17051633" target="_blank">Potential Factors Influencing Repeated SARS Outbreaks in China</a>
# Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.
# <a href="https://doi.org/10.1016/j.tmaid.2020.101633" target="_blank">Should the Holy Week 2020 be cancelled in Latin America due to the COVID-19 pandemic?</a><br/><a href="https://doi.org/10.1016/j.jobb.2020.02.001" target="_blank">Deliberate release: Plague – A review</a><br/><a href="https://doi.org/10.1016/j.tmaid.2020.101622" target="_blank">COVID 19: Will the 2020 Hajj pilgrimage and Tokyo Olympic Games be cancelled?</a><br/><a href="https://doi.org/10.1016/j.pulmoe.2020.02.010" target="_blank">And now for something completely different: from 2019-nCoV and COVID-19 to 2020-nMan</a><br/><a href="https://doi.org/10.1016/j.idh.2020.04.001" target="_blank">Hajj in the Time of COVID-19</a>
# Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia
# Approaches to evaluate risk for enhanced disease after vaccination
# <a href="https://doi.org/10.1016/j.coi.2020.01.006" target="_blank">DNA vaccines: prime time is now</a><br/><a href="https://doi.org/10.1016/j.medidd.2020.100026" target="_blank">Novel decoy cellular vaccine strategy utilizing transgenic antigen-expressing cells as immune presenter and adjuvant in vaccine prototype against SARS-CoV-2 virus</a><br/><a href="https://doi.org/10.1016/j.immuni.2020.03.007" target="_blank">SARS-CoV-2 Vaccines: Status Report</a><br/><a href="https://doi.org/10.1016/j.it.2020.04.001" target="_blank">Improving vaccine-induced immunity: Can Baseline Predict Outcome?</a><br/><a href="https://doi.org/10.1016/j.mehy.2020.109707" target="_blank">Is Global BCG Vaccination Coverage Relevant To The Progression Of SARS-CoV-2 Pandemic?</a>
# Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models [in conjunction with therapeutics]
# <a href="https://doi.org/10.1016/j.coi.2020.01.006" target="_blank">DNA vaccines: prime time is now</a><br/><a href="https://doi.org/10.1016/j.medidd.2020.100026" target="_blank">Novel decoy cellular vaccine strategy utilizing transgenic antigen-expressing cells as immune presenter and adjuvant in vaccine prototype against SARS-CoV-2 virus</a><br/><a href="https://doi.org/10.1016/j.immuni.2020.03.007" target="_blank">SARS-CoV-2 Vaccines: Status Report</a><br/><a href="https://doi.org/10.1016/j.it.2020.04.001" target="_blank">Improving vaccine-induced immunity: Can Baseline Predict Outcome?</a><br/><a href="https://doi.org/10.1016/j.mehy.2020.109707" target="_blank">Is Global BCG Vaccination Coverage Relevant To The Progression Of SARS-CoV-2 Pandemic?</a>

# %% [markdown]
# ## What has been published about ethical and social science considerations?

# %%
relevant_articles(task6, 5, only_covid19=True)
# Out:
# Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019
# <a href="https://doi.org/10.1016/s2468-2667(20)30074-8" target="_blank">The Italian health system and the COVID-19 challenge</a><br/><a href="https://doi.org/10.1016/s0140-6736(20)30795-9" target="_blank">Medical student involvement in the COVID-19 response</a><br/><a href="https://doi.org/10.1016/j.ijsu.2020.03.082" target="_blank">The impact of despecialisation and redeployment on surgical training in the midst of the COVID-19 pandemic</a><br/><a href="https://doi.org/10.1016/j.ajic.2020.04.003" target="_blank">Will the status of infection prevention and control (IPC) professionals be improved in the context of COVID-19?</a><br/><a href="https://doi.org/10.1016/s2468-2667(20)30060-8" target="_blank">The resilience of the Spanish health system against the COVID-19 pandemic</a>
# Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://doi.org/10.1016/s0140-6736(20)30795-9" target="_blank">Medical student involvement in the COVID-19 response</a>
# Efforts to support sustained education, access, and capacity building in the area of ethics
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.sapharm.2020.04.002" target="_blank">Pharmacy Emergency Preparedness and Response (PEPR) framework for expanding pharmacy professionals’ roles and contributions to emergency preparedness and response during the COVID-19 pandemic and beyond</a>
# Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences.
# <a href="https://doi.org/10.1016/j.chb.2020.106357" target="_blank">Cyberpsychology research and COVID-19</a><br/><a href="https://doi.org/10.1016/j.synbio.2020.03.002" target="_blank">Prudently conduct the engineering and synthesis of the SARS-CoV-2 virus</a><br/><a href="https://doi.org/10.1016/j.clsr.2020.105431" target="_blank">Data Protection and Research: A vital challenge in the era of Covid-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.indmarman.2020.02.017" target="_blank">Teaching-practice as a critical bridge for narrowing the research-practice gap</a><br/><a href="https://doi.org/10.1016/j.forpol.2020.102165" target="_blank">Advanced approaches for a better understanding of scientific knowledge transfer in forest and forest-related policy</a>
# Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures)
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://doi.org/10.1016/s0140-6736(20)30795-9" target="_blank">Medical student involvement in the COVID-19 response</a>
# Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed
efforts to develop a core clinical outcome set to maximize usability of data across a range of trials
# <a href="https://doi.org/10.1016/j.jcrc.2020.03.011" target="_blank">Poor survival with extracorporeal membrane oxygenation in acute respiratory distress syndrome (ARDS) due to coronavirus disease 2019 (COVID-19): Pooled analysis of early reports</a><br/><a href="https://doi.org/10.1101/2020.04.03.020602" target="_blank">Real-time biomedical knowledge synthesis of the exponentially growing world wide web using unsupervised neural networks</a><br/><a href="https://doi.org/10.1101/2020.03.31.20049007" target="_blank">Harmonizing heterogeneous endpoints in COVID-19 trials without loss of information - an essential step to facilitate decision making</a><br/><a href="https://doi.org/10.1101/2020.04.07.20056788" target="_blank">Treatment with ACE-inhibitors is associated with less severe disease with SARS-Covid-19 infection in a multi-site UK acute Hospital Trust</a><br/><a href="https://doi.org/10.1016/j.pcad.2020.03.001" target="_blank">Cardiac troponin I in patients with coronavirus disease 2019 (COVID-19): Evidence from a meta-analysis</a>
# Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen)
# <a href="https://doi.org/10.1016/j.jacc.2020.04.016" target="_blank">Considerations for Drug Interactions on QTc in Exploratory COVID-19 (Coronavirus Disease 2019) Treatment</a><br/><a href="https://doi.org/10.1016/j.jaccas.2020.04.001" target="_blank">The Imperfect Cytokine Storm: Severe COVID-19 with ARDS in Patient on Durable LVAD Support</a><br/><a href="https://doi.org/10.1016/j.jaccas.2020.03.007" target="_blank">Reacquainting Cardiology with Mechanical Ventilation in Response to the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.hrthm.2020.03.024" target="_blank">SARS-CoV-2, COVID-19 and inherited arrhythmia syndromes</a><br/><a href="https://doi.org/10.1016/j.jaccas.2020.03.006" target="_blank">Exploring Personal Protection During High-Risk PCI in a COVID-19 Patient Impella CP Mechanical Support During ULMCA Bifurcation Stenting</a>

# %% [markdown]
# ## What has been published about information sharing and inter-sectoral collaboration?

# %%
relevant_articles(task9, 5, only_covid19=True)
# Out:
# Methods for coordinating data-gathering with standardized nomenclature.
# <a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7152572/" target="_blank">Coronavirus Goes Viral: Quantifying the COVID-19 Misinformation Epidemic on Twitter</a><br/><a href="https://doi.org/10.1101/2020.04.03.20052936" target="_blank">An "Infodemic": Leveraging High-Volume Twitter Data to Understand Public Sentiment for the COVID-19 Outbreak</a><br/><a href="https://doi.org/10.1101/2020.03.16.20036723" target="_blank">Building a COVID-19 Vulnerability Index</a><br/><a href="https://doi.org/10.1101/2020.03.19.20039354" target="_blank">AI-assisted CT imaging analysis for COVID-19 screening: Building and deploying a medical AI system in four weeks</a><br/><a href="https://doi.org/10.1101/2020.03.30.20047308" target="_blank">Predicting Mortality Risk in Patients with COVID-19 Using Artificial Intelligence to Help Medical Decision-Making</a>
# Sharing response information among planners, providers, and others.
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.sapharm.2020.04.002" target="_blank">Pharmacy Emergency Preparedness and Response (PEPR) framework for expanding pharmacy professionals’ roles and contributions to emergency preparedness and response during the COVID-19 pandemic and beyond</a>
# Understanding and mitigating barriers to information-sharing.
# <a href="https://doi.org/10.1016/j.sheji.2020.02.002" target="_blank">She Ji: The Next Five Years</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7093265/" target="_blank">Preprints: What is their role in medical journals?</a><br/><a href="https://doi.org/10.1016/j.resconrec.2020.104828" target="_blank">On general principles at the sustainability science-policy interface</a><br/><a href="https://doi.org/10.1016/j.ijid.2020.03.020" target="_blank">Estimation of the asymptomatic ratio of novel coronavirus infections (COVID-19)</a><br/><a href="https://doi.org/10.1016/j.forpol.2020.102165" target="_blank">Advanced approaches for a better understanding of scientific knowledge transfer in forest and forest-related policy</a>
# How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic).
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://doi.org/10.1016/s0140-6736(20)30795-9" target="_blank">Medical student involvement in the COVID-19 response</a>
# Integration of federal/state/local public health surveillance systems.
# <a href="https://doi.org/10.1016/j.encep.2020.03.002" target="_blank">In Times of Crisis, Anticipate Mourning</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.sapharm.2020.04.002" target="_blank">Pharmacy Emergency Preparedness and Response (PEPR) framework for expanding pharmacy professionals’ roles and contributions to emergency preparedness and response during the COVID-19 pandemic and beyond</a>
#
a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7151353/" target="_blank">Fighting COVID-19: Enabling Graduating Students to Start Internship Early at Their Own Medical School</a><br/><a href="https://doi.org/10.1016/j.adaj.2020.03.038" target="_blank">Ethical practice during the COVID-19 pandemic</a><br/><a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7106065/" target="_blank">Supporting Clinicians During the COVID-19 Pandemic</a><br/><a href="https://doi.org/10.1016/j.sapharm.2020.04.002" target="_blank">Pharmacy Emergency Preparedness and Response (PEPR) framework for expanding pharmacy professionals’ roles and contributions to emergency preparedness and response during the COVID-19 pandemic and beyond</a>

# %% [markdown]
# # Widget: Pick a Task

# %% [markdown]
# Here you can easily pick a bullet point of one of the tasks and see some related articles.

# %%
def relevant_articles_for_task():
    def main_function(bullet, task, k=5, year_range=[1950, 2020], only_covid19=False):
        relevant_articles([bullet], k, lower=year_range[0], upper=year_range[1], only_covid19=only_covid19)
        bulletW.options = tasks[task]    

    yearW = widgets.IntRangeSlider(min=1950, max=2020, value=[2010, 2020], description='Year Range', 
                                   continuous_update=False, layout=Layout(width='40%'))
    covidW = widgets.Checkbox(value=True,description='Only COVID-19-Papers',disabled=False, indent=False, layout=Layout(width='20%'))
    kWidget = widgets.IntSlider(value=10, description='k', max=50, min=1, layout=Layout(width='30%'))

    taskW = widgets.Dropdown(options=tasks.keys(), layout=Layout(width='90%', height='50px'), description='Task:')
    init = taskW.value
    bulletW = widgets.Select(options=tasks[init], layout=Layout(width='90%', height='200px'), description='Bullet Point:')

    widget = widgets.interactive(main_function, task=taskW, bullet=bulletW, k=kWidget, year_range=yearW, only_covid19=covidW)
    
    controls = VBox([HBox([widget.children[2], widget.children[3], widget.children[4]], layout=Layout(width='90%', justify_content='space-around')),
                     widget.children[1],
                     widget.children[0]], layout=Layout(align_items='center'))
    
    output = widget.children[-1]
    display(VBox([controls, output]))

# %%
relevant_articles_for_task()
# Out:
# VBox(children=(VBox(children=(HBox(children=(IntSlider(value=10, description='k', layout=Layout(width='30%'), …

# %% [markdown]
# # Widget: Free Text Search

# %% [markdown]
# In this widget you can insert any kind of text (abstract, paragraph, full text, keywords, questions, ...) and find related articles.

# %%
def relevant_articles_for_text():    
    textW = widgets.Textarea(
        value='',
        placeholder='Type something',
        description='',
        disabled=False,
        layout=Layout(width='90%', height='200px')
    )

    yearW = widgets.IntRangeSlider(min=1950, max=2020, value=[2010, 2020], description='Year Range', 
                               continuous_update=False, layout=Layout(width='40%'))
    covidW = widgets.Checkbox(value=True,description='Only COVID-19-Papers',disabled=False, indent=False, layout=Layout(width='25%'))
    kWidget = widgets.IntSlider(value=10, description='k', max=50, min=1, layout=Layout(width='25%'))

    button = widgets.Button(description="Search")

    display(VBox([HBox([kWidget, yearW, covidW], layout=Layout(width='90%', justify_content='space-around')),
        textW, button], layout=Layout(align_items='center')))

    def on_button_clicked(b):
        clear_output()
        display(VBox([HBox([kWidget, yearW, covidW], layout=Layout(width='90%', justify_content='space-around')),
            textW, button], layout=Layout(align_items='center')))        
        relevant_articles(textW.value, kWidget.value, yearW.value[0], yearW.value[1], covidW.value)

    button.on_click(on_button_clicked)

# %%
relevant_articles_for_text()
# Out:
# VBox(children=(HBox(children=(IntSlider(value=10, description='k', layout=Layout(width='25%'), max=50, min=1),…
